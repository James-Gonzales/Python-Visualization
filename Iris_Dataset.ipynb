# %% [markdown]
# <a href="https://colab.research.google.com/github/James-Gonzales/Python-Visualization/blob/main/Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
rs = sns.load_dataset("iris")
rs
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
brplot = sns.barplot(x = 'species', y = 'petal_width',data = rs,palette = "Set1")
brplot.set(xlabel = 'Species', ylabel = 'Petal Width' )
# Out:
# [Text(0, 0.5, 'Petal Width'), Text(0.5, 0, 'Species')]

# %%
sns.boxplot(x = 'species', y = 'petal_width',data = rs,palette = "coolwarm")

# %%
sns.boxplot(x = 'species', y = 'petal_width',data = rs,hue ='species',  palette = "Set1")

# %%
sns.violinplot(x = 'species', y = 'petal_width',data = rs,palette = "Set1")

# %%
sns.scatterplot(data = rs , x = "sepal_length", y = "petal_width")

# %%
sns.catplot(x="species", y="petal_width",  data = rs)

# %%
sns.histplot(rs['petal_width'], color = 'b',kde = False)

# %%
sns.histplot(rs['petal_width'], color = 'b',kde = True)

# %%
sns.distplot(rs['sepal_length'],hist=False, bins=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(rs['petal_width'],  kde = True, bins = 10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.stripplot(x='species', y="petal_width", data=rs)

# %%
sns.set(style = 'whitegrid') 
sns.stripplot(x="sepal_length", y="petal_length", hue="species", data=rs)

# %%
sns.swarmplot(x='species', y="petal_width", data=rs)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="sepal_length", y="sepal_width", hue="species", data=rs)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.regplot(x="petal_length", y="sepal_length", data=rs)

# %%
sns.lmplot(x="petal_length", y="petal_width", data=rs)

# %%
sns.lmplot(x="petal_length", y="petal_width", data=rs, x_estimator=np.mean)

# %%
rs.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(rs.corr(), cmap="coolwarm", annot=True)

# %%
sns.lineplot(x="petal_length", y="petal_width",data = rs)

# %%
rs.plot(figsize = (12,5))
plt.show()

# %%
rs.plot(figsize = (12,5), linewidth = 5,fontsize = 10)
plt.xlabel("species", fontsize = 10)
# Out:
# Text(0.5, 0, 'species')

# %%
sns.pairplot(rs)
